# %%
df = spark.read.table("bronze_hospital_information")
# Out:
# StatementMeta(, 87ca25b0-9f2b-4e3d-8cca-304ddd91c04b, 4, Finished, Available, Finished, False)

# %%
display(df)
# Out:
# StatementMeta(, 87ca25b0-9f2b-4e3d-8cca-304ddd91c04b, 5, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, d59b83ca-7c78-49a9-b8fe-4bedb7cd3b49)

# %%
df.printSchema()
# Out:
# StatementMeta(, 87ca25b0-9f2b-4e3d-8cca-304ddd91c04b, 6, Finished, Available, Finished, False)
# root
#  |-- Facility_ID: double (nullable = true)
#  |-- Facility_Name: string (nullable = true)
#  |-- Address: string (nullable = true)
#  |-- City_Town: string (nullable = true)
#  |-- State: string (nullable = true)
#  |-- ZIP_Code: integer (nullable = true)
#  |-- County_Parish: string (nullable = true)
#  |-- Telephone_Number: string (nullable = true)
#  |-- Hospital_Type: string (nullable = true)
#  |-- Hospital_Ownership: string (nullable = true)
#  |-- Emergency_Services: string (nullable = true)
#  |-- Meets_criteria_for_birthing_friendly_designation: string (nullable = true)
#  |-- Hospital_overall_rating: string (nullable = true)
#  |-- Hospital_overall_rating_footnote: string (nullable = true)
#  |-- MORT_Group_Measure_Count: string (nullable = true)
#  |-- Count_of_Facility_MORT_Measures: string (nullable = true)
# ...

# %%
print(df.count())
# Out:
# StatementMeta(, 87ca25b0-9f2b-4e3d-8cca-304ddd91c04b, 7, Finished, Available, Finished, False)
# 5432

# %%
df = df.dropDuplicates()
# Out:
# StatementMeta(, 87ca25b0-9f2b-4e3d-8cca-304ddd91c04b, 8, Finished, Available, Finished, False)

# %%
from pyspark.sql.functions import col, sum

df.select([
    sum(col(c).isNull().cast("int")).alias(c)
    for c in df.columns
]).show()
# Out:
# StatementMeta(, 87ca25b0-9f2b-4e3d-8cca-304ddd91c04b, 9, Finished, Available, Finished, False)
# ...

# %%
print("Rows before cleaning:", df.count())
# Out:
# StatementMeta(, 87ca25b0-9f2b-4e3d-8cca-304ddd91c04b, 10, Finished, Available, Finished, False)
# Rows before cleaning: 5432

# %%
df = df.dropDuplicates()

print("Rows after removing duplicates:", df.count())
# Out:
# StatementMeta(, 87ca25b0-9f2b-4e3d-8cca-304ddd91c04b, 11, Finished, Available, Finished, False)
# Rows after removing duplicates: 5432

# %%
from pyspark.sql.functions import col, sum

df.select([
    sum(col(c).isNull().cast("int")).alias(c)
    for c in df.columns
]).show(vertical=True, truncate=False)
# Out:
# StatementMeta(, 87ca25b0-9f2b-4e3d-8cca-304ddd91c04b, 12, Finished, Available, Finished, False)
# -RECORD 0------------------------------------------------
#  Facility_ID                                      | 0
#  Facility_Name                                    | 0
#  Address                                          | 0
#  City_Town                                        | 0
#  State                                            | 0
#  ZIP_Code                                         | 0
#  County_Parish                                    | 0
#  Telephone_Number                                 | 0
#  Hospital_Type                                    | 0
#  Hospital_Ownership                               | 0
#  Emergency_Services                               | 0
#  Meets_criteria_for_birthing_friendly_designation | 3169
#  Hospital_overall_rating                          | 0
#  Hospital_overall_rating_footnote                 | 3111
# ...

# %%
df = df.fillna({
    "Hospital_overall_rating_footnote": "Unknown",
    "MORT_Group_Footnote": "Unknown",
    "Safety_Group_Footnote": "Unknown",
    "READM_Group_Footnote": "Unknown",
    "Meets_criteria_for_birthing_friendly_designation": "Unknown"
})
# Out:
# StatementMeta(, 87ca25b0-9f2b-4e3d-8cca-304ddd91c04b, 13, Finished, Available, Finished, False)

# %%
from pyspark.sql.functions import col, sum

df.select([
    sum(col(c).isNull().cast("int")).alias(c)
    for c in df.columns
]).show(vertical=True, truncate=False)
# Out:
# StatementMeta(, 87ca25b0-9f2b-4e3d-8cca-304ddd91c04b, 14, Finished, Available, Finished, False)
# -RECORD 0------------------------------------------------
#  Facility_ID                                      | 0
#  Facility_Name                                    | 0
#  Address                                          | 0
#  City_Town                                        | 0
#  State                                            | 0
#  ZIP_Code                                         | 0
#  County_Parish                                    | 0
#  Telephone_Number                                 | 0
#  Hospital_Type                                    | 0
#  Hospital_Ownership                               | 0
#  Emergency_Services                               | 0
#  Meets_criteria_for_birthing_friendly_designation | 0
#  Hospital_overall_rating                          | 0
#  Hospital_overall_rating_footnote                 | 0
#  MORT_Group_Measure_Count                         | 0
# ...

# %%
df = df.fillna({
    "Meets_criteria_for_birthing_friendly_designation": "Unknown",
    "Hospital_overall_rating_footnote": "Unknown",
    "MORT_Group_Footnote": "Unknown",
    "Safety_Group_Footnote": "Unknown",
    "READM_Group_Footnote": "Unknown",
    "Pt_Exp_Group_Footnote": "Unknown",
    "TE_Group_Footnote": "Unknown"
})
# Out:
# StatementMeta(, 87ca25b0-9f2b-4e3d-8cca-304ddd91c04b, 15, Finished, Available, Finished, False)

# %%
from pyspark.sql.functions import col, sum

df.select([
    sum(col(c).isNull().cast("int")).alias(c)
    for c in df.columns
]).show(vertical=True, truncate=False)
# Out:
# StatementMeta(, 87ca25b0-9f2b-4e3d-8cca-304ddd91c04b, 16, Finished, Available, Finished, False)
# -RECORD 0------------------------------------------------
#  Facility_ID                                      | 0
#  Facility_Name                                    | 0
#  Address                                          | 0
#  City_Town                                        | 0
#  State                                            | 0
#  ZIP_Code                                         | 0
#  County_Parish                                    | 0
#  Telephone_Number                                 | 0
#  Hospital_Type                                    | 0
#  Hospital_Ownership                               | 0
#  Emergency_Services                               | 0
#  Meets_criteria_for_birthing_friendly_designation | 0
#  Hospital_overall_rating                          | 0
#  Hospital_overall_rating_footnote                 | 0
#  MORT_Group_Measure_Count                         | 0
# ...

# %%
df = df.fillna({
    "Meets_criteria_for_birthing_friendly_designation": "Unknown",
    "Hospital_overall_rating_footnote": "Unknown",
    "MORT_Group_Footnote": "Unknown",
    "Safety_Group_Footnote": "Unknown",
    "READM_Group_Footnote": "Unknown",
    "Pt_Exp_Group_Footnote": "Unknown",
    "TE_Group_Footnote": "Unknown"
})
# Out:
# StatementMeta(, 87ca25b0-9f2b-4e3d-8cca-304ddd91c04b, 17, Finished, Available, Finished, False)

# %%
from pyspark.sql.functions import sum, col

df.select([
    sum(col(c).isNull().cast("int")).alias(c)
    for c in df.columns
]).show(vertical=True, truncate=False)
# Out:
# StatementMeta(, 87ca25b0-9f2b-4e3d-8cca-304ddd91c04b, 18, Finished, Available, Finished, False)
# -RECORD 0------------------------------------------------
#  Facility_ID                                      | 0
#  Facility_Name                                    | 0
#  Address                                          | 0
#  City_Town                                        | 0
#  State                                            | 0
#  ZIP_Code                                         | 0
#  County_Parish                                    | 0
#  Telephone_Number                                 | 0
#  Hospital_Type                                    | 0
#  Hospital_Ownership                               | 0
#  Emergency_Services                               | 0
#  Meets_criteria_for_birthing_friendly_designation | 0
#  Hospital_overall_rating                          | 0
#  Hospital_overall_rating_footnote                 | 0
#  MORT_Group_Measure_Count                         | 0
# ...

# %%
df.filter(
    df.MORT_Group_Footnote.isNull()
).count()
# Out:
# StatementMeta(, 87ca25b0-9f2b-4e3d-8cca-304ddd91c04b, 19, Finished, Available, Finished, False)
# 4032

# %%
df.filter(
    df.TE_Group_Footnote.isNull()
).count()
# Out:
# StatementMeta(, 87ca25b0-9f2b-4e3d-8cca-304ddd91c04b, 20, Finished, Available, Finished, False)
# 4422

# %%
from pyspark.sql.functions import col

df.select("MORT_Group_Footnote").distinct().show(20, truncate=False)
# Out:
# StatementMeta(, 87ca25b0-9f2b-4e3d-8cca-304ddd91c04b, 21, Finished, Available, Finished, False)
# +-------------------+
# |MORT_Group_Footnote|
# +-------------------+
# |22                 |
# |5                  |
# |19                 |
# |23                 |
# |29                 |
# |NULL               |
# +-------------------+

# %%
df.select("TE_Group_Footnote").distinct().show(20, truncate=False)
# Out:
# StatementMeta(, 87ca25b0-9f2b-4e3d-8cca-304ddd91c04b, 22, Finished, Available, Finished, False)
# +-----------------+
# |TE_Group_Footnote|
# +-----------------+
# |22               |
# |16               |
# |5                |
# |19               |
# |29               |
# |NULL             |
# +-----------------+

# %%
df.printSchema()
# Out:
# StatementMeta(, 87ca25b0-9f2b-4e3d-8cca-304ddd91c04b, 23, Finished, Available, Finished, False)
# root
#  |-- Facility_ID: double (nullable = true)
#  |-- Facility_Name: string (nullable = true)
#  |-- Address: string (nullable = true)
#  |-- City_Town: string (nullable = true)
#  |-- State: string (nullable = true)
#  |-- ZIP_Code: integer (nullable = true)
#  |-- County_Parish: string (nullable = true)
#  |-- Telephone_Number: string (nullable = true)
#  |-- Hospital_Type: string (nullable = true)
#  |-- Hospital_Ownership: string (nullable = true)
#  |-- Emergency_Services: string (nullable = true)
#  |-- Meets_criteria_for_birthing_friendly_designation: string (nullable = false)
#  |-- Hospital_overall_rating: string (nullable = true)
#  |-- Hospital_overall_rating_footnote: string (nullable = false)
#  |-- MORT_Group_Measure_Count: string (nullable = true)
#  |-- Count_of_Facility_MORT_Measures: string (nullable = true)
# ...

# %%
df = df.fillna({
    "MORT_Group_Footnote": -1,
    "Safety_Group_Footnote": -1,
    "READM_Group_Footnote": -1,
    "Pt_Exp_Group_Footnote": -1,
    "TE_Group_Footnote": -1
})
# Out:
# StatementMeta(, 87ca25b0-9f2b-4e3d-8cca-304ddd91c04b, 24, Finished, Available, Finished, False)

# %%
df.filter(df.MORT_Group_Footnote.isNull()).count()
# Out:
# StatementMeta(, 87ca25b0-9f2b-4e3d-8cca-304ddd91c04b, 25, Finished, Available, Finished, False)
# 0

# %%
df.write.mode("overwrite").format("delta").saveAsTable("hospital_silver")
# Out:
# StatementMeta(, 87ca25b0-9f2b-4e3d-8cca-304ddd91c04b, 26, Finished, Available, Finished, False)

# %%
spark.sql("SHOW TABLES").show(truncate=False)
# Out:
# StatementMeta(, 87ca25b0-9f2b-4e3d-8cca-304ddd91c04b, 27, Finished, Available, Finished, False)
# +--------------------------------------+--------------------------------+-----------+
# |namespace                             |tableName                       |isTemporary|
# +--------------------------------------+--------------------------------+-----------+
# |`My workspace`.HealthcareLakehouse.dbo|bronze_hospital_information     |false      |
# |`My workspace`.HealthcareLakehouse.dbo|bronze_provider_services        |false      |
# |`My workspace`.HealthcareLakehouse.dbo|bronze_unplanned_hospital_visits|false      |
# |`My workspace`.HealthcareLakehouse.dbo|hospital_silver                 |false      |
# +--------------------------------------+--------------------------------+-----------+
